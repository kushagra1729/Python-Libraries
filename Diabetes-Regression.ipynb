# %%
from sklearn.datasets import load_diabetes
diabetes=load_diabetes()
X=diabetes.data
Y=diabetes.target

# %%
print(diabetes.feature_names)
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
prediction=model.predict(X_test)
print(prediction)
print(Y_test)
# Out:
# [ 122.41932407  111.48365055  184.18558652   68.52087272  171.44221745
#   191.06463336  220.61738089  117.98679452  156.5524466   126.49478122
#   213.88062061  199.98328703   90.87507124   79.36223511  234.96537061
#   204.19340103  176.94030006  101.88594035  111.86181655  170.60381844
#   185.83614993   82.11394798  140.77629148  106.88120017   92.28592319
#   212.31820792   92.21122242  176.92601402  119.67674197  181.00300506
#   156.75743341  138.82248129  197.06334156   98.33667675  163.42298972
#   190.93523247  107.61370587  246.79405     172.97198996  186.61704933
#   162.58918571  180.1143173   118.5461696   121.61931807  145.27196886]
# [  78.  152.  200.   59.  311.  178.  332.  132.  156.  135.  220.  233.
#    91.   51.  195.  109.  217.   94.   89.  111.  129.  181.  168.   97.
#   115.  202.   84.  147.  253.  144.  262.  115.   68.   65.  252.  212.
#   142.  215.  180.  163.  151.  283.   66.   83.  214.]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(X_test[:,0], Y_test,  color='black')
plt.plot(X_test[:,0], prediction , color='blue') #it is not a straight line since the relation is not only dependent on that variable since a lot many variables are involved
plt.show()
